# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhernandez1488/mi_hobby/blob/main/Copia_de_PPS_recuperaci%C3%B3n_Actividad_6_Filtramos_datos_y_generamos_mapas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prácticas Profesionalizantes 2024
# EEST 9
#
# # Filtramos datos y generamos mapas

# %% [markdown]
# # Seguimos trabajando con el datasets elegido en el trabajo anterior
#
# Bajar nuevamente para  probrar los ejemplos y realizar algunos ejercicios el dataset:
# * [Lagos argentinos](https://archivos.linti.unlp.edu.ar/index.php/s/D25I4PCPXGHL8Ee)
#     * Nombre del archivo: lagos_arg.csv
#     * Descargado de: https://www.ign.gob.ar/NuestrasActividades/Geografia/DatosArgentina/Lagos

# %% [markdown]
# * [Aeropuertos Argentina](https://archivos.linti.unlp.edu.ar/index.php/s/vd9SIytO2ABbkAo).
#     * Nombre del archivo: ar-airports.csv
#     * Descargado de: https://ourairports.com/countries/AR/airports.csv
# * [Áreas protegidas](https://archivos.linti.unlp.edu.ar/index.php/s/Eqw1eAVC1pdefmb).
#     * Nombre del archivo: area_protegida.csv
#     * Descargado de: https://dnsg.ign.gob.ar/apps/api/v1/capas-sig/Geodesia+y+demarcaci%C3%B3n/L%C3%ADmites/area_protegida/csv
# * [Conectivdad Argentina](https://archivos.linti.unlp.edu.ar/index.php/s/3k2TO5sSzaAU6IY).
#     * Nombre del archivo: Conectividad_Internet.csv
#     * Descargado de :https://datos.gob.ar/dataset/enacom-conectividad-al-servicio-internet/archivo/enacom_CONEC-AL-SERVI-DE-INTER_0
# * [Datos sobre consumo cultural](https://archivos.linti.unlp.edu.ar/index.php/s/pf8NMFtr1bwxFtT).
#     * Nombre del archivo: encc_2017.csv
#     * Descargado de: https://datos.cultura.gob.ar/dataset/encuesta-nacional-de-consumos-culturales
# * [Avistajes de felinos en Argentina](https://archivos.linti.unlp.edu.ar/index.php/s/5iC9FrYWiGi11d0).
#     * Nombre del archivo: felinos_filtrado.csv
#     * Descargado de: https://www.gbif.org/

# %% [markdown]
# # Veamos otros ejemplos para filtrar datos

# %%
import pandas as pd
file_data = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSjVPKXeckqcb1Jw0uvWzLlRoATEDSHX04rLYZof2SW4VWudozUoCcwdg6tKgv96kY_TyzZ_mSsrkIQ/pub?gid=146677787&single=true&output=csv')
file_data.Ubicación.unique()
# Out:
# array(['Santa Cruz', 'Río Negro / Neuquén', 'Chubut', 'Buenos Aires',
#        'Río Negro', 'Neuquén',
#        'Tierra del Fuego, Antártida e Islas del Atlántico Sur'],
#       dtype=object)

# %% [markdown]
# Veamos un ejemplo donde consulto sobre los lagos de la provincia de **Santa Cruz**

# %%
file_data[file_data.Ubicación=='Santa Cruz']
# Out:
#                     Nombre   Ubicación  Superficie (km²)  \
# 0           Lago Argentino  Santa Cruz              1435
# 1              Lago Viedma  Santa Cruz              1166
# 4             Lago Cardiel  Santa Cruz               358
# 7             Lago Strobel  Santa Cruz               100
# 12               Lago Ghío  Santa Cruz                65
# 17            Lago Quiroga  Santa Cruz                47
# 19             Lago Nansen  Santa Cruz                42
# 20           Lago Belgrano  Santa Cruz                42
# 22            Lago Posadas  Santa Cruz                41
# 26  Lago Salitroso o Sucio  Santa Cruz                37
# 28                Lago Tar  Santa Cruz                30
# 32  Lago Asador o Guitarra  Santa Cruz                23
# 37      Lago Quiroga Chico  Santa Cruz                20
# 42              Lago Azara  Santa Cruz                16
# 43         Lago Burmeister  Santa Cruz                14
# ...

# %% [markdown]
# # 1. Realizá la consulta para ver los lagos de la provincia de **Chubut**

# %%
#acá arma la respuesta
import pandas as pd
file_data = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSjVPKXeckqcb1Jw0uvWzLlRoATEDSHX04rLYZof2SW4VWudozUoCcwdg6tKgv96kY_TyzZ_mSsrkIQ/pub?gid=146677787&single=true&output=csv')
file_data.Ubicación.unique()
file_data[file_data.Ubicación=='Chubut']
# Out:
#                Nombre Ubicación  Superficie (km²)  Profundidad máxima (m)  \
# 3        Lago Musters    Chubut               427                    39.0
# 8        Lago Fontana    Chubut                84                     NaN
# 11      Lago La Plata    Chubut                73                     NaN
# 13      Lago Menéndez    Chubut                58                   287.0
# 18         Lago Puelo    Chubut                47                   180.0
# 21  Lago Futalaufquen    Chubut                42                   168.0
# 30        Lago Blanco    Chubut                28                     NaN
# 33     Lago Rivadavia    Chubut                23                   147.0
# 36     Lago Río Chico    Chubut                20                     NaN
# 38        Lago Epuyén    Chubut                17                   148.0
# 40       Lago Cholila    Chubut                17                   108.0
# 49     Lago Pico Nº 1    Chubut                10                     NaN
# ...

# %% [markdown]
# # 2. Utilizando el dataset elegido filtrar datos por la columna *type*:
# * Explicar qué se están filtrando

# %%
#acá arma la respuesta
import pandas as pd
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
datos_aeropuertos_argentina.type.unique()

#Filtra y muestra los aeropuertos que están clasificados como "large_airport", es decir, grandes aeropuertos.
datos_aeropuertos_argentina[datos_aeropuertos_argentina.type=='large_airport']



#datos_aeropuertos_argentina[datos_aeropuertos_argentina.type=='medium_airport']
#datos_aeropuertos_argentina[datos_aeropuertos_argentina.type=='closed']
#datos_aeropuertos_argentina[datos_aeropuertos_argentina.type=='small_airport']
#datos_aeropuertos_argentina[datos_aeropuertos_argentina.type=='heliport']
#datos_aeropuertos_argentina[datos_aeropuertos_argentina.type=='balloonport']

#'large_airport' 'medium_airport' 'closed' 'small_airport' 'heliport''balloonport'
# Out:
#      id ident           type                                      name  \
# 0  5781  SAEZ  large_airport  Minister Pistarini International Airport
# 1  5771  SABE  large_airport                     Jorge Newbery Airpark
#
#        lat      lng  elevation_ft continent country_name iso_country  ...  \
# 0 -34.8222 -58.5358          67.0        SA    Argentina          AR  ...
# 1 -34.5592 -58.4156          18.0        SA    Argentina          AR  ...
#
#             municipality scheduled_service gps_code iata_code  local_code  \
# 0  Buenos Aires (Ezeiza)                 1     SAEZ       EZE         EZE
# 1           Buenos Aires                 1     SABE       AEP         AER
#
#                             home_link  \
# 0  http://www.aa2000.com.ar/index.php
# 1                                 NaN
#
#                                       wikipedia_link     keywords score  \
# 0  https://en.wikipedia.org/wiki/Ministro_Pistari...  BUE, Ezeiza  1275
# ...

# %% [markdown]
# # 3. Utilizando el dataset elegido filtrar datos por la columna *elevation_ft* ':
# * Explicar qué se están filtrando

# %%
import pandas as pd
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
valores_unicos_elevation_ft = datos_aeropuertos_argentina['elevation_ft'].unique()
cantidad_valores_unicos_elevation_ft = len(valores_unicos_elevation_ft)
print(f'Valores únicos en la columna "elevation_ft":{valores_unicos_elevation_ft}')
print(f'Cantidad de valores únicos en la columna "elevation_ft":{cantidad_valores_unicos_elevation_ft}')
# Out:
# Valores únicos en la columna "elevation_ft":[6.7000e+01 1.8000e+01 1.0200e+02 6.6900e+02 9.1600e+02 2.3100e+03
#  2.7740e+03 4.0880e+03 1.6040e+03 1.0260e+03 6.1000e+01 1.0000e+01
#  8.5000e+01 1.8900e+02 1.4100e+02 2.0300e+02 8.9500e+02 5.5000e+01
#  6.5000e+01 2.4600e+02 7.2000e+01 4.3000e+02 6.3000e+02 5.9000e+01
#  2.3600e+02 4.2700e+02 9.5000e+01 2.0000e+01 1.5220e+03 2.5690e+03
#  2.6210e+03 2.6800e+02 3.6400e+02 1.7300e+02 1.4930e+03 3.0190e+03
#  9.0000e+00 1.1200e+02 1.9000e+01 1.4370e+03 2.4200e+02 1.4100e+03
#  1.9580e+03 6.5600e+02 1.4720e+03 1.5910e+03 5.7400e+02 2.1320e+03
#  3.2000e+01 3.5600e+02 1.6700e+02 1.3000e+01 4.2900e+02 1.1380e+03
#  7.8000e+01 1.6460e+03 1.4160e+03 9.0300e+02 9.8000e+01 1.0500e+02
#  6.0000e+00 8.2000e+01 1.3700e+02 9.9700e+02 1.9300e+02 1.2700e+02
#  2.0200e+02 2.3280e+03 2.4700e+03 1.0820e+03 9.3500e+02 7.3200e+02
#  1.3800e+03 1.2800e+02 7.5000e+01 2.6200e+02 2.3000e+02 2.7800e+02
# ...

# %%
#acá arma la respuesta
import pandas as pd
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
datos_aeropuertos_argentina.elevation_ft.unique()
#El filtrado por la columna elevation_ft permite obtener una lista de aeropuertos que se encuentran a una altitud específica sobre el nivel del mar, en este caso, aquellos que tienen una elevación de 67 pies.
datos_aeropuertos_argentina[datos_aeropuertos_argentina.elevation_ft==6.7000e+01]
# Out:
#      id ident           type                                      name  \
# 0  5781  SAEZ  large_airport  Minister Pistarini International Airport
#
#        lat      lng  elevation_ft continent country_name iso_country  ...  \
# 0 -34.8222 -58.5358          67.0        SA    Argentina          AR  ...
#
#             municipality scheduled_service gps_code iata_code  local_code  \
# 0  Buenos Aires (Ezeiza)                 1     SAEZ       EZE         EZE
#
#                             home_link  \
# 0  http://www.aa2000.com.ar/index.php
#
#                                       wikipedia_link     keywords score  \
# 0  https://en.wikipedia.org/wiki/Ministro_Pistari...  BUE, Ezeiza  1275
#
#                 last_updated
# 0  2022-10-27T15:05:29+00:00
#
# [1 rows x 23 columns]

# %% [markdown]
# ### ¿Cómo podemos filtrar por más de un criterio?

# %%
file_data[(file_data.Ubicación=='Santa Cruz') & (file_data['Superficie (km²)']>15)]
# Out:
#                     Nombre   Ubicación  Superficie (km²)  \
# 0           Lago Argentino  Santa Cruz              1435
# 1              Lago Viedma  Santa Cruz              1166
# 4             Lago Cardiel  Santa Cruz               358
# 7             Lago Strobel  Santa Cruz               100
# 12               Lago Ghío  Santa Cruz                65
# 17            Lago Quiroga  Santa Cruz                47
# 19             Lago Nansen  Santa Cruz                42
# 20           Lago Belgrano  Santa Cruz                42
# 22            Lago Posadas  Santa Cruz                41
# 26  Lago Salitroso o Sucio  Santa Cruz                37
# 28                Lago Tar  Santa Cruz                30
# 32  Lago Asador o Guitarra  Santa Cruz                23
# 37      Lago Quiroga Chico  Santa Cruz                20
# 42              Lago Azara  Santa Cruz                16
#
#     Profundidad máxima (m)  Profundidad media (m)            Coordenadas  \
# ...

# %% [markdown]
# Aca estamos filtrando por:
# * la provincia de **Santa Cruz** y la **superficie** sea mayor a 15
# * las columnas donde hago las consultas para filtrar son: **Ubicación** y **Superficie (km²)**

# %% [markdown]
# # 4. ¿Qué lago de Tierra del Fuego , Antártida e Islas del Atlántico Sur tiene una superficie mayor a 40?
# **Nota**: ¿hay algún problema con las filas de esa provincia? Si es así arreglarlo.

# %%
# arma acá la respuesta
import pandas as pd
file_data = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSjVPKXeckqcb1Jw0uvWzLlRoATEDSHX04rLYZof2SW4VWudozUoCcwdg6tKgv96kY_TyzZ_mSsrkIQ/pub?gid=146677787&single=true&output=csv')
file_data['Profundidad máxima (m)'] = file_data['Profundidad máxima (m)'].fillna(0)
file_data[(file_data.Ubicación=='Tierra del Fuego, Antártida e Islas del Atlántico Sur') & (file_data['Superficie (km²)']>40)]
# Out:
#          Nombre                                          Ubicación  \
# 16  Lago Yehuin  Tierra del Fuego, Antártida e Islas del Atlánt...
#
#     Superficie (km²)  Profundidad máxima (m)  Profundidad media (m)  \
# 16                49                     0.0                   43.0
#
#               Coordenadas Sup Tamaño Latitud en GMS Longitud en GMS  \
# 16  54°24'43"S 67°42'55"O      medio     54°24'43"S      67°42'55"O
#
#           lat        lng
# 16 -54.411944 -67.715278

# %% [markdown]
# # 5.Indicar la lista y cantidad de aeropuertos que tienen una altura mayor a 900
#
# *   Elemento de la lista
# *   Elemento de la lista

# %%
# arma acá la respuesta
import pandas as pd
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
nombres_columnas = datos_aeropuertos_argentina.columns
aeropuertos_altos = datos_aeropuertos_argentina[(datos_aeropuertos_argentina['elevation_ft'])>900]
lista_aeropuertos_altos = aeropuertos_altos['name'].tolist()
cantidad_aeropuertos_altos = len(lista_aeropuertos_altos)
print(f"Lista de aeropuertos con elevación mayor a 900 pies ({cantidad_aeropuertos_altos} aeropuertos):")
for aeropuerto in lista_aeropuertos_altos:
    print(aeropuerto)
# Out:
# Lista de aeropuertos con elevación mayor a 900 pies (228 aeropuertos):
# Cataratas Del Iguazú International Airport
# El Plumerillo Airport
# San Carlos De Bariloche Airport
# Martin Miguel De Guemes International Airport
# Ingeniero Ambrosio Taravella Airport
# Colonia Catriel Airport
# Coronel Felipe Varela International Airport
# Aviador C. Campos Airport
# Brigadier Antonio Parodi Airport
# Teniente Benjamin Matienzo Airport
# Gobernador Horacio Guzman International Airport
# Capitan V A Almonacid Airport
# Perito Moreno Airport
# Domingo Faustino Sarmiento Airport
# General Enrique Mosconi Airport
# Villa Reynolds Airport
# Cutral-Co Airport
# Veinticinco De Mayo Airport
# Escuela de Aviación Militar (Military Aviation School) Airport
# Coronel Olmedo Airport
# Lago Viedma Airstrip
# Pigüé Airport
# Brigadier Mayor D Cesar Raul Ojeda Airport
# Suboficial Ay Santiago Germano Airport
# Las Heras Airport
# Termas de Río Hondo international Airport
# Area De Material Airport
# ...

# %% [markdown]
# # 6. Vimos como saber la cantidad de valores nulos de todo el dataset con:
# ```python
# nombre_dataframe.isnull().sum()
#  ```
#  Para saber qué filas son las que tienen valores nulos de una columna usamos:
#  ```python
#  nombre_dataframe[nombre_dataframe.nombre_columna.isna()]
# ```
#  Mostrá las filas de la columna que tiene mayor cantidad de valores nulos.

# %%
# arma acá la respuesta
import pandas as pd
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
datos_aeropuertos_argentina.isnull().sum()
# Out:
# id                     0
# ident                  0
# type                   0
# name                   0
# lat                    0
# lng                    0
# elevation_ft          35
# continent              0
# country_name           0
# iso_country            0
# region_name            0
# iso_region             0
# local_region           0
# municipality          16
# scheduled_service      0
# gps_code             718
# iata_code            840
# local_code           182
# home_link            929
# wikipedia_link       862
# keywords             835
# score                  0
# last_updated           0
# dtype: int64

# %%
# arma acá la respuesta
import pandas as pd
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
datos_aeropuertos_argentina[datos_aeropuertos_argentina.home_link.isna()]
# Out:
#          id    ident            type  \
# 1      5771     SABE   large_airport
# 2      5835     SAWH  medium_airport
# 5      5786     SAME  medium_airport
# 7      5811     SASA  medium_airport
# 8      5773     SACO  medium_airport
# ..      ...      ...             ...
# 938  333824  AR-0654          closed
# 939   42893  AR-0471        heliport
# 940  333815  AR-0652          closed
# 941   42903  AR-0481        heliport
# 942   42905  AR-0483        heliport
#
#                                                   name        lat        lng  \
# 1                                Jorge Newbery Airpark -34.559200 -58.415600
# 2                          Malvinas Argentinas Airport -54.843300 -68.295800
# 5                                El Plumerillo Airport -32.831699 -68.792900
# 7        Martin Miguel De Guemes International Airport -24.856001 -65.486198
# 8                 Ingeniero Ambrosio Taravella Airport -31.323601 -64.208000
# ...

# %% [markdown]
# # 6. Respondé si las siguientes afirmaciones son correctas y justificar en ambos casos:
# ## a. ¿Hay 223 aeropuertos que tienen elevación menor o igual a 131?
# ## b. En base a la cantidad de valores nulos de las columnas,  de todos los aeropuertos en el dataset, la elevación media es 801.696035.
# ## c. Los aeropuertos de tipo  **large_airport** tienen los datos completos en la columna de elevación.
#
# Para caca inciso generá los códigos correspondientes que justifican la respuesta.

# %%
# Respuesta inciso a
import pandas as pd
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
aeropuertos_bajos = datos_aeropuertos_argentina[datos_aeropuertos_argentina['elevation_ft'] <= 131]
cantidad_aeropuertos = len(aeropuertos_bajos)
if cantidad_aeropuertos == 223:
    print("Sí, hay exactamente 223 aeropuertos que tienen elevación menor o igual a 131 pies.")
else:
    print(f"No, no hay exactamente 223 aeropuertos con elevación menor o igual a 131 pies. Encontrados: {cantidad_aeropuertos}")
# Out:
# No, no hay exactamente 223 aeropuertos con elevación menor o igual a 131 pies. Encontrados: 227

# %%
# Respuesta inciso b
import pandas as pd
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')

valores_nulos_por_columna = datos_aeropuertos_argentina.isnull().sum()

# Calcular la elevación media
elevacion_media = datos_aeropuertos_argentina['elevation_ft'].mean()

# Imprimir resultados
print("Cantidad de valores nulos por columna:")
print(valores_nulos_por_columna)
print("\nElevación media de todos los aeropuertos:")
print(elevacion_media)

# Verificar si la elevación media es aproximadamente 801.696035
if round(elevacion_media, 6) == 801.696035:
    print("\nLa elevación media es exactamente 801.696035 pies.")
else:
    print(f"\nLa elevación media no es exactamente 801.696035 pies, es {elevacion_media:.6f} pies.")
# Out:
# Cantidad de valores nulos por columna:
# id                     0
# ident                  0
# type                   0
# name                   0
# lat                    0
# lng                    0
# elevation_ft          35
# continent              0
# country_name           0
# iso_country            0
# region_name            0
# iso_region             0
# local_region           0
# municipality          16
# scheduled_service      0
# gps_code             718
# iata_code            840
# local_code           182
# home_link            929
# wikipedia_link       862
# keywords             835
# score                  0
# last_updated           0
# dtype: int64
#
# Elevación media de todos los aeropuertos:
# 801.6960352422908
#
# La elevación media es exactamente 801.696035 pies.

# %%
# Respuesta inciso c
import pandas as pd
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
datos_aeropuertos_argentina[datos_aeropuertos_argentina.type=='large_airport']
# Out:
#      id ident           type                                      name  \
# 0  5781  SAEZ  large_airport  Minister Pistarini International Airport
# 1  5771  SABE  large_airport                     Jorge Newbery Airpark
#
#        lat      lng  elevation_ft continent country_name iso_country  ...  \
# 0 -34.8222 -58.5358          67.0        SA    Argentina          AR  ...
# 1 -34.5592 -58.4156          18.0        SA    Argentina          AR  ...
#
#             municipality scheduled_service gps_code iata_code  local_code  \
# 0  Buenos Aires (Ezeiza)                 1     SAEZ       EZE         EZE
# 1           Buenos Aires                 1     SABE       AEP         AER
#
#                             home_link  \
# 0  http://www.aa2000.com.ar/index.php
# 1                                 NaN
#
#                                       wikipedia_link     keywords score  \
# 0  https://en.wikipedia.org/wiki/Ministro_Pistari...  BUE, Ezeiza  1275
# ...

# %% [markdown]
# ## Veamos nuestros datos en un mapa

# %%
import folium

# %% [markdown]
# ## Primero: Tenemos que ubicar donde en qué **columnas** están los datos de :
# * latitud
# * longitud

# %%
file_data = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSjVPKXeckqcb1Jw0uvWzLlRoATEDSHX04rLYZof2SW4VWudozUoCcwdg6tKgv96kY_TyzZ_mSsrkIQ/pub?gid=146677787&single=true&output=csv')

# %%
file_data.columns
# Out:
# Index(['Nombre', 'Ubicación', 'Superficie (km²)', 'Profundidad máxima (m)',
#        'Profundidad media (m)', 'Coordenadas', 'Sup Tamaño', 'Latitud en GMS',
#        'Longitud en GMS', 'lat', 'lng'],
#       dtype='object')

# %% [markdown]
# En este caso las columnas con las **coordendas** son:
# * 'lat'
# * 'lng'

# %% [markdown]
# ## Segundo vamos a generar un mapa **base** para luego agregar los puntos

# %%
def generar_mapa():
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
    )

    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = folium.Map(
        location=(-33.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

# %% [markdown]
# Usamos la función **generar_mapa** para tener nuestro mapa base esto igual para todos los **datasets**

# %%
mapa = generar_mapa()

# %% [markdown]
# La variable **mapa** es nuestro mapa **base**

# %% [markdown]
# ### Tercero agregamos a nuestro mapa:
# En la celda de abajo pusimos el código para poder agregar los puntos, te contamos lo más importante para tener en cuenta.
# * los puntos que se encuentran en las columnas de las **coordenadas**
# ```python
# [row['lat'], row['lng']],
# ```
# * queremos que muestre el nombre del lago cuando hacemos clic sobre cada icono, por eso pusimos el nombre de la columna donde se encuentra **ese dato**
# ```python
# popup=row['Nombre']
# ```

# %%
mapa = generar_mapa()
def agregar_marca_lago(row):
    folium.Marker(
        [row['lat'], row['lng']],
        popup=row['Nombre'],
        icon=folium.Icon()
        ).add_to(mapa)
file_data.apply(agregar_marca_lago, axis=1)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # 7. Armá tu mapa con el dataset **aeropuertos**
# Con el dataset elegido mostrá los datos en un mapa

# %% [markdown]
# ## Primero encontrá los nombres de las columnas donde están las coordenadas

# %%
#pone acá el código
import pandas as pd
import folium
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
datos_aeropuertos_argentina.columns
# Out:
# Index(['id', 'ident', 'type', 'name', 'lat', 'lng', 'elevation_ft',
#        'continent', 'country_name', 'iso_country', 'region_name', 'iso_region',
#        'local_region', 'municipality', 'scheduled_service', 'gps_code',
#        'iata_code', 'local_code', 'home_link', 'wikipedia_link', 'keywords',
#        'score', 'last_updated'],
#       dtype='object')

# %% [markdown]
# ## Segundo creá tu mapa **base**

# %%
# pone acá el codigo aca
def generar_mapa():
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
    )

    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = folium.Map(
        location=(-33.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

# %% [markdown]
# ## Tercero agregá los puntos a tu mapa, acordáte de poner la columna que contiene el nombre del aeropuerto

# %%
mapa = generar_mapa()

# %%
mapa = generar_mapa()
def agregar_marca_aeropuerto(row):
    folium.Marker(
        [row['lat'], row['lng']],
        popup=row['name'],
        icon=folium.Icon()
        ).add_to(mapa)
datos_aeropuertos_argentina.apply(agregar_marca_aeropuerto, axis=1)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
