# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhernandez1488/mi_hobby/blob/main/Copia_de_PPS_recuperaci%C3%B3n_Actividad_5_Intro_analisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prácticas Profesionalizantes 2024
# EEST 9
#
# # Actividad 4
#
# #Conociendo qué es un dataset y qué datos contiene

# %% [markdown]
# ## Trabajo en grupo entre 2 o 3 estudiantes
# Indicar los nombres y los links de los repositorios de la actividad 3 de los integrantes:
# * nombre - repositorio

# %% [markdown]
# ## 1.Descargue uno de los siguientes archivos y responda las siguientes preguntas
# * [Aeropuertos Argentina](https://archivos.linti.unlp.edu.ar/index.php/s/vd9SIytO2ABbkAo).
#   * Descargado de: https://ourairports.com/countries/AR/airports.csv
# * [Áreas protegidas](https://archivos.linti.unlp.edu.ar/index.php/s/Eqw1eAVC1pdefmb).
#   * Descargado de: https://dnsg.ign.gob.ar/apps/api/v1/capas-sig/Geodesia+y+demarcaci%C3%B3n/L%C3%ADmites/area_protegida/csv
# * [Conectivdad Argentina](https://archivos.linti.unlp.edu.ar/index.php/s/3k2TO5sSzaAU6IY).
#   * Descargado de :https://datos.gob.ar/dataset/enacom-conectividad-al-servicio-internet/archivo/enacom_CONEC-AL-SERVI-DE-INTER_0
# * [Lagos Argentinos](https://archivos.linti.unlp.edu.ar/index.php/s/LBNPS7EdmNSwt8z).
#   * Descargado de: https://www.ign.gob.ar/NuestrasActividades/Geografia/DatosArgentina/Lagos
#
# * [Avistajes de felinos en Argentina](https://archivos.linti.unlp.edu.ar/index.php/s/5iC9FrYWiGi11d0).
#   * Descargado de: https://www.gbif.org/

# %% [markdown]
# ## Ahora trabajaremos con python y la librería pandas

# %% [markdown]
# Para trabajar con el archivo utilizaremos la librería pandas, primero la importamos

# %%
import pandas as pd

# %% [markdown]
# Luego abrimos el archivo con la librería **pandas**
# * la función **read_csv**. Se pueden abrir otros tipos de archivos con otroas funciones.
# * la sentencia **columns** lista los nombres de las columnas
# ```python
# nombre_variable = pd.read_csv('nombre_archivo.csv')
# nombre_variable.columns
# ```

# %% [markdown]
# ## 2.Indique los nombres de las columnas

# %%
#Respuesta
import pandas as pd
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
nombres_columnas = datos_aeropuertos_argentina.columns
print(f'Nombres de las columnas: {nombres_columnas}')
# Out:
# Nombres de las columnas: Index(['id', 'ident', 'type', 'name', 'lat', 'lng', 'elevation_ft',
#        'continent', 'country_name', 'iso_country', 'region_name', 'iso_region',
#        'local_region', 'municipality', 'scheduled_service', 'gps_code',
#        'iata_code', 'local_code', 'home_link', 'wikipedia_link', 'keywords',
#        'score', 'last_updated'],
#       dtype='object')

# %% [markdown]
# ## 3.Indique el tipo de dato de la variable:
# ```python
# type(nombre_variable)
# ```

# %%
#Respuesta
import pandas as pd
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
tipo_de_dato = type(datos_aeropuertos_argentina)
print(f'El tipo de dato de la variable datos_aeropuertos_argentina es: {tipo_de_dato}')
# Out:
# El tipo de dato de la variable datos_aeropuertos_argentina es: <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## 4. Ahora con python vamos a buscar la misma información que encontramos con la aplicación
# * Indique la cantidad de:
#     * filas
#     * columnas
# * Indique cuáles y cuántos valores únicos contiene la **columna especificada** según el dataset elegido.

# %% [markdown]
# *  Aeropuertos Argentina:type
# * Áreas protegidas: tap
# * Lagos Argentinos: Ubicación
# * Conectivdad Argentina: elegir una de las tecnologías: ADSL 	CABLEMODEM 	DIALUP 	FIBRAOPTICA 	SATELITAL 	WIRELESS 	TELEFONIAFIJA

# %% [markdown]
# Utilizamos **shape** para saber la cantidad de filas  y columnas:
# ```python
# nombre_dataframe.shape
# ```

# %%
#respuesta
import pandas as pd
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
filas, columnas = datos_aeropuertos_argentina.shape
print(f'Cantidad de filas: {filas}')
print(f'Cantidad de columnas: {columnas}')
#valores_unicos_type = datos_aeropuertos_argentina['type'].unique()
#cantidad_valores_unicos_type = len(valores_unicos_type)
#print(f'Valores únicos en la columna "type":{valores_unicos_type}')
#print(f'Cantidad de valores únicos en la columna "type":{cantidad_valores_unicos_type}')
# Out:
# Cantidad de filas: 943
# Cantidad de columnas: 23

# %% [markdown]
# Utilizamos el método unique para saber los valores únicos de una columna:
# ```python
# nombre_dataframe.nombre_columna.unique()

# %%
#respuesta
import pandas as pd
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
#filas, columnas = datos_aeropuertos_argentina.shape
#print(f'Cantidad de filas: {filas}')
#print(f'Cantidad de columnas: {columnas}')
valores_unicos_type = datos_aeropuertos_argentina['type'].unique()
cantidad_valores_unicos_type = len(valores_unicos_type)
print(f'Valores únicos en la columna "type":{valores_unicos_type}')
print(f'Cantidad de valores únicos en la columna "type":{cantidad_valores_unicos_type}')
# Out:
# Valores únicos en la columna "type":['large_airport' 'medium_airport' 'closed' 'small_airport' 'heliport'
#  'balloonport']
# Cantidad de valores únicos en la columna "type":6

# %% [markdown]
# ## 5. Indique si las columnas contienen valores nulos

# %% [markdown]
# La sentencia **isnull().sum()** suma la cantidad de valores nulos de cada columna del dataframe
# ```
# nombre_dataframe.isnull().sum()
# ```

# %%
import pandas as pd
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
valores_nulos_por_columna = datos_aeropuertos_argentina.isnull().sum()
print('Valores nulos por columna:')
print(valores_nulos_por_columna)
# Out:
# Valores nulos por columna:
# id                     0
# ident                  0
# type                   0
# name                   0
# lat                    0
# lng                    0
# elevation_ft          35
# continent              0
# country_name           0
# iso_country            0
# region_name            0
# iso_region             0
# local_region           0
# municipality          16
# scheduled_service      0
# gps_code             718
# iata_code            840
# local_code           182
# home_link            929
# wikipedia_link       862
# keywords             835
# score                  0
# last_updated           0
# dtype: int64

# %% [markdown]
# ## Graficamos
# Les dejamos un ejemplo, ustedes reemplacen con los datos del dataset elegido.
#
# ### Guardar los valores únicos del dataset y realizar un gráfico de barra
# ```python
# file_data.columna.unique()
# import matplotlib.pyplot as plt
# # Crear el gráfico de barras
# conteo_columnas = file_data['columnas_elegida'].value_counts()
# conteo_columnas.plot(kind='bar', color='skyblue')
#
# # Agregar etiquetas y título
# plt.xlabel('Titulo correcto')
# plt.ylabel('Cantidad de datos elegidos')
# plt.title('Titutlo del gráfico')
#
# # Mostrar el gráfico
# plt.show()
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
conteo_columnas = datos_aeropuertos_argentina['type'].value_counts()
conteo_columnas.plot(kind='bar', color='skyblue')
plt.xlabel('Tipo de aeropuerto')
plt.ylabel('Cantidad')
plt.title('Cantidad de aeropuertos por tipo')
plt.show()

# %% [markdown]
# ## 6. Hacer un gráfico con la columnas de valores únicos en barra del dataset elegido
# Seguir el ejemplo y reemplazar por los datos del dataset elegido

# %%
# completar con las instrucicones para generar el gráfico
import pandas as pd
import matplotlib.pyplot as plt
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
conteo_columnas = datos_aeropuertos_argentina['score'].value_counts()
conteo_columnas.plot(kind='bar', color='skyblue')
plt.xlabel('Puntuación')
plt.ylabel('Cantidad')
plt.title('Cantidad de aeropuertos por puntuación')
plt.show()

# %% [markdown]
# ## 7.Crear el gráfico de torta
# * Investigar en la página de [Matplotlib](https://matplotlib.org/) cuál es el parámetro que cambia para hacer un gráfico de torta
# * ¿Qué otros tipos de gráficos se pueden realizar?

# %% [markdown]
# respuesta: Gridded data,Statistical distributions,Pairwise data and Irregularly gridded data

# %%
#completar
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
datos_aeropuertos_argentina = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSyDciqZ_jkvAtX-11_p-hup0lYHoOmlpiQsA8cqZJEEWDMz4cOeytExpxESHk09WCaAcZnMvHt76ED/pub?gid=294700430&single=true&output=csv')
conteo_tipos = datos_aeropuertos_argentina['type'].value_counts()
tipos = conteo_tipos.index
valores = conteo_tipos.values

# Define colors for the pie chart using the 'tab20' colormap
#En lugar de la paleta Blues, se usa tab20, que proporciona una mayor variedad de colores contrastantes, mejorando la distinción entre las diferentes porciones del gráfico.
#colores = plt.cm.Blues(np.linspace(0.2, 0.7, len(tipos)))

colores = plt.cm.tab20(np.linspace(0, 1, len(tipos)))
plt.figure(figsize=(10, 6))
wedges, texts, autotexts = plt.pie(valores, labels=None, colors=colores, autopct='%1.1f%%', startangle=140, pctdistance=0.85)
plt.pie(valores, labels=None, colors=colores, autopct='%1.1f%%', startangle=140, pctdistance=0.85)
plt.setp(autotexts, size=10, weight="bold")
plt.setp(texts, size=10)
plt.title('Distribución de Tipos de Aeropuertos en Argentina')
plt.legend(tipos, loc='best', bbox_to_anchor=(1, 0.5))
plt.show()
